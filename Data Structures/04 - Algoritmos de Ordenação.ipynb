# %% [markdown]
# # **Aula 04 - Algoritmos de Ordenação (Métodos Simples)**

# %% [markdown]
# ## **Considerações**
# Ordenação é o processo de colocar elementos em uma dada ordem. Existem muitos algoritmos de ordenação já desenvolvidos e analisados. Nessa e na próxima aula, discutiremos algumas destas técnicas e as compararemos de acordo com o seu tempo de execução.

# %% [markdown]
# ## **Métodos Simples**

# %% [markdown]
# - São programas pequenos e fáceis de entender. Porém, são adequados para pequenos vetores.
# - Possuem complexidade $C(n) = 𝑂(𝑛²)$, ou seja, requerem $𝑂(𝑛²)$ comparações.
# - Exemplos: Bubble Sort, Insertion Sort, Selection Sort, Shell Sort, Comb Sort.

# %% [markdown]
# ### **Bubble Sort**

# %% [markdown]
# Realiza múltiplas passagem por uma lista. Ele compara itens adjacentes e troca aqueles que estão fora de ordem. Cada passagem pela lista coloca o próximo maior valor na sua posição correta. A figura abaixo ilustra a primeira passada do algoritmo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# No começo da segunda passagem, o maior valor agora está ordenado. Como cada passagem coloca o próximo maior valor encontrado no lugar certo, o número total de passagens necessárias para ordenar um vetor de tamanho/comprimento $n$ será $𝑛−1$.
#
# Animação: https://visualgo.net/en/sorting?slide=1

# %% [markdown]
# ####**Swap**

# %% [markdown]
# A troca de dois elementos numa lista requer o uso de uma variável para armazenamento temporário, conforme trecho de código abaixo:

# %%
alist = [3,2,1] # [2,3,1]

temp = alist[0] # temp -> 3
alist[0] = alist[1] # alist -> [2,2,1]
alist[1] = temp # alist -> [2,3,1]

print(alist)
# Out:
# [2, 3, 1]

# %% [markdown]
# Porém, em Python, é possível realizar atribuições simultâneas, conforme exemplo abaixo:

# %%
alist = [3,2,1]

alist[0], alist[1] = alist[1], alist[0]

print(alist)
# Out:
# [2, 3, 1]

# %% [markdown]
# ####**Implementação**

# %%
def bubbleSort(alist):

  n = len(alist)

  for p in range(n-1): # passagens do algoritmo

    for i in range(0,n-1-p): # itens adjacentes

      if alist[i] > alist[i+1]:

        alist[i], alist[i+1] = alist[i+1], alist[i]

    print('passagem', p+1, alist)

# %% [markdown]
# #### **Execução**

# %%
#alist = [54,26,93,17,77,31,44,55,20]
alist = [54,26,103,17,27,31,4,55,20]

bubbleSort(alist)
# Out:
# passagem 1 [26, 54, 17, 27, 31, 4, 55, 20, 103]
# passagem 2 [26, 17, 27, 31, 4, 54, 20, 55, 103]
# passagem 3 [17, 26, 27, 4, 31, 20, 54, 55, 103]
# passagem 4 [17, 26, 4, 27, 20, 31, 54, 55, 103]
# passagem 5 [17, 4, 26, 20, 27, 31, 54, 55, 103]
# passagem 6 [4, 17, 20, 26, 27, 31, 54, 55, 103]

# %% [markdown]
# #### **Análise**

# %% [markdown]
# ![Captura de Tela 2020-12-01 às 10.44.50.png](data:image/png;base64,...)

# %% [markdown]
# - $𝑛−1$ passagens serão realizadas para ordenar uma lista de tamanho $𝑛$;
# - A soma das comparações é uma PA: $𝑛-1 + 𝑛-2 + 𝑛-3 + ... + 3 + 2 + 1$;
# - Lembre-se de que essa soma pode ser calculada como: $𝑛²/2 - 𝑛/2$;
#   - para $𝑛 = 4$, temos $𝑛²/2 = 8$ e $𝑛/2 = 2$.
#   - para $𝑛 = 1000$, temos $𝑛²/2 = 500.000$ e $𝑛/2 = 500$.
# - Ou seja, $𝑂(𝑛²)$ comparações.

# %% [markdown]
# #### **Exercício**

# %% [markdown]
# 1. Suponha que você tenha a seguinte lista de números para ordenar: [19, 1, 9, 7, 3, 10, 13, 15, 8, 12] qual lista representa a lista parcialmente ordenada depois de três passagens completas do bubble sort?
#
#  A. [1, 9, 19, 7, 3, 10, 13, 15, 8, 12]
#
#  B. [1, 3, 7, 9, 10, 8, 12, 13, 15, 19]
#
#  C. [1, 7, 3, 9, 10, 13, 8, 12, 15, 19]
#
#  D. [1, 9, 19, 7, 3, 10, 13, 15, 8, 12]

# %% [markdown]
# ### **Selection Sort (Ordenação Por Seleção)**

# %% [markdown]
# Melhora o bubble sort, ao realizar apenas uma troca a cada passagem pela lista. Para conseguir isso, uma ordenação por seleção procura pelo valor mais alto enquanto faz uma passagem e, depois de completá-la, coloca-o na posição correta. Assim como o bubble sort, depois da primeira passagem, o maior item sempre está na posição correta. Depois da segunda passagem, o próximo maior item também vai para a posição adequada. O processo continua dessa forma e demanda $𝑛−1$ passagens para ordenar $𝑛$ itens, já que o item final deverá estar no lugar certo depois da ($𝑛−1$)-ésima passagem. A figura abaixo ilustra o processo de ordenação completo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Animação: https://visualgo.net/en/sorting

# %% [markdown]
# ####**Implementação**

# %%
def selectionSort(alist):

  n = len(alist)

  for slot in range(n-1,0,-1):

    i_max=0

    for i in range(1,slot+1):

      if alist[i]>alist[i_max]:

        i_max = i

    alist[slot], alist[i_max] = alist[i_max], alist[slot]

    print('slot', slot, alist)

# %% [markdown]
# #### **Execução**

# %%
alist = [54,26,93,17,77,31,44,55,20]
selectionSort(alist)
# Out:
# slot 8 [54, 26, 20, 17, 77, 31, 44, 55, 93]
# slot 7 [54, 26, 20, 17, 55, 31, 44, 77, 93]
# slot 6 [54, 26, 20, 17, 44, 31, 55, 77, 93]
# slot 5 [31, 26, 20, 17, 44, 54, 55, 77, 93]
# slot 4 [31, 26, 20, 17, 44, 54, 55, 77, 93]
# slot 3 [17, 26, 20, 31, 44, 54, 55, 77, 93]
# slot 2 [17, 20, 26, 31, 44, 54, 55, 77, 93]
# slot 1 [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# #### **Análise**

# %% [markdown]
# Você pode ver que a ordenação por seleção faz o mesmo número de comparações que o bubble sort. Portanto, também é $𝑂(𝑛²)$. Contudo, devido à redução do número de trocas, a ordenação por seleção tipicamente executa mais rápido em análises de desempenho. Na verdade, para a nossa lista, o bubble sort realiza 20 trocas, enquanto a ordenação por seleção faz apenas 8.

# %% [markdown]
# #### **Exercício**

# %% [markdown]
# 1. Suponha que você tenha a seguinte lista de números para ordenar: [11, 7, 12, 14, 19, 1, 6, 18, 8, 20] qual lista representa a lista parcialmente ordenada depois de três passagens completas da ordenação por seleção?
#
#   A. [7, 11, 12, 1, 6, 14, 8, 18, 19, 20]
#
#   B. [7, 11, 12, 14, 19, 1, 6, 18, 8, 20]
#
#   C. [11, 7, 12, 14, 1, 6, 8, 18, 19, 20]
#
#   D. [11, 7, 12, 14, 8, 1, 6, 18, 19, 20]

# %% [markdown]
# ### **Insertion Sort (Ordenação por Inserção)**

# %% [markdown]
# Embora também seja $𝑂(𝑛²)$, funciona de uma forma ligeiramente diferente. Ele sempre mantém uma sublista ordenada nas posições inferiores da lista. Cada novo item é “inserido” na sublista anterior de modo que a sublista ordenada fique com um item a mais. A figura abaixo mostra o processo de ordenação por inserção. Itens sombreados representam as sublistas ordenadas conforme cada passagem feita pelo algoritmo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Animação: https://visualgo.net/en/sorting
#
# Começamos pressupondo que uma lista com um único item (posição 0) está ordenada. A cada passagem, ou seja, do item $1$ a $𝑛−1$, o item atual é comparado com os que já estão na sublista ordenada. Conforme vamos caminhando de trás pra frente na sublista já ordenada, movemos os itens que são maiores para a direita. Quando encontramos um item menor ou chegamos ao fim da sublista, o item atual é inserido.

# %% [markdown]
# A figura abaixo mostra a quinta passagem em detalhe. Nesse ponto do algoritmo, há uma sublista com cinco itens: 17, 26, 54, 77 e 93. Queremos inserir 31 nesse conjunto já ordenado. A primeira comparação faz com que o item 93 vá para a direita. Os itens 77 e 54 também são deslocados para frente. Quando o item 26 é encontrado, o processo de deslocamento para e o 31 é colocado na lacuna aberta. Temos agora uma sublista ordenada com seis itens.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Implementação**

# %%
def insertionSort(alist):

  n = len(alist)

  for i in range(1,n):

    value, position = alist[i], i

    while position>0 and alist[position-1]>value:

      alist[position]=alist[position-1]

      position -= 1

    alist[position]=value

    print(alist)

# %% [markdown]
# ####**Execução**

# %%
alist = [54,26,93,17,77,31,44,55,20]
insertionSort(alist)
# Out:
# [26, 54, 93, 17, 77, 31, 44, 55, 20]
# [26, 54, 93, 17, 77, 31, 44, 55, 20]
# [17, 26, 54, 93, 77, 31, 44, 55, 20]
# [17, 26, 54, 77, 93, 31, 44, 55, 20]
# [17, 26, 31, 54, 77, 93, 44, 55, 20]
# [17, 26, 31, 44, 54, 77, 93, 55, 20]
# [17, 26, 31, 44, 54, 55, 77, 93, 20]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ####**Análise**

# %% [markdown]
# O número máximo de comparações para uma ordenação por inserção é a soma dos primeiros $𝑛−1$ inteiros. De novo, isso é $𝑂(𝑛²)$. Contudo, no melhor caso, apenas uma comparação é necessária a cada passagem. Esse seria o caso de uma lista já ordenada. Uma observação importante sobre a diferença entre deslocamento e troca: em geral, a operação de deslocamento requer aproximadamente um terço de processamento de uma troca, já que apenas uma atribuição é feita. Em estudos de desempenho, a ordenação por inserção costuma mostrar ótimos resultados.

# %% [markdown]
# ####**Exercício**

# %% [markdown]
# 1. Suponha que você tenha a seguinte lista de números para ordenar: [15, 5, 4, 18, 12, 19, 14, 10, 8, 20] qual lista representa a lista parcialmente ordenada depois três passagens completas da ordenação por inserção?
#
#   A. [4, 5, 12, 15, 14, 10, 8, 18, 19, 20]
#
#   B. [15, 5, 4, 10, 12, 8, 14, 18, 19, 20]
#
#   C. [4, 5, 15, 18, 12, 19, 14, 10, 8, 20]
#
#   D. [15, 5, 4, 18, 12, 19, 14, 8, 10, 20]

# %% [markdown]
# ### **Shell Sort**

# %% [markdown]
# É o mais eficiente algoritmo de ordenação dentre os de complexidade quadrática $𝑂(𝑛²)$. É um refinamento do método *Insertion Sort*, melhorando a ordenação ao quebrar a lista original em sublistas, as quais são ordenadas usando a técnica de ordenação por inserção. Isso pode ser visto nas figuras abaixo, numa lista com  nove itens. Se usarmos um incremento de três, serão três sublistas, cada uma sendo submetida à ordenação por inserção.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A figura abaixo mostra uma ordenação por inserção final usando um incremento de um. Observa-se que ao realizar as ordenações de sublistas anteriores, o número total de operações de deslocalmento necessárias para colocar a lista na sua ordem final é reduzido. Nesse caso, precisa-se de apenas mais quatro deslocamentos para completar o processo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Implementação**

# %%
def gapInsertionSort(alist,inicio,gap):

  for i in range(inicio+gap,len(alist),gap):

    valor_atual, posicao = alist[i], i

    while posicao>=gap and alist[posicao-gap]>valor_atual:

      alist[posicao]=alist[posicao-gap]

      posicao = posicao-gap

    alist[posicao]=valor_atual

# %%
def shellSort(alist):

  tamanho = len(alist)//2

  while tamanho > 0:

    for posicao_inicial in range(tamanho):

      gapInsertionSort(alist,posicao_inicial,tamanho)

    print("Depois do incremento de tamanho de", tamanho, "a lista é",alist)

    tamanho = tamanho // 2

# %% [markdown]
# ####**Execução**

# %%
alist = [54,26,93,17,77,31,44,55,20]
shellSort(alist)
print(alist)
# Out:
# Depois do incremento de tamanho de 4 a lista é [20, 26, 44, 17, 54, 31, 93, 55, 77]
# Depois do incremento de tamanho de 2 a lista é [20, 17, 44, 26, 54, 31, 77, 55, 93]
# Depois do incremento de tamanho de 1 a lista é [17, 20, 26, 31, 44, 54, 55, 77, 93]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ####**Análise**

# %% [markdown]
# Pode-se pensar que o *Shell Sort* não tem como ser melhor que o *Insertion Sort*, já que ele a utiliza na lista toda como um último passo. Acontece que essa ordenação por inserção final não precisa realizar muitos deslocamentos, já que a lista foi pré-ordenada por ordenações por inserção incrementais anteriores. Em outras palavras, cada passagem produz uma lista que está “mais ordenada” que a anterior. Isso faz com que a passagem final seja muito eficiente. Embora uma análise geral do *Shell Sort* esteja além do escopo deste documento, pode-se dizer que ele tende a ficar entre $𝑂(𝑛)$ e $𝑂(𝑛²)$. Para o incremento mostrado na implementação, o desempenho é $𝑂(𝑛²)$. Alterando o incremento, por exemplo, usando $2^k−1$ (1, 3, 7, 15, 31, e assim por diante), o *Shell Sort* pode executar a $O(n^{3/2})$.

# %% [markdown]
# ####**Exercício**

# %% [markdown]
# 1. Dada a seguinte lista de números: [5, 16, 20, 12, 3, 8, 9, 17, 19, 7] Que resposta exibe o conteúdo correto da lista depois que todas as trocas são feitas para um gap de tamanho 3?
#
#   A. [5, 3, 8, 7, 16, 19, 9, 17, 20, 12]
#
#   B. [3, 7, 5, 8, 9, 12, 19, 16, 20, 17]
#
#   C. [3, 5, 7, 8, 9, 12, 16, 17, 19, 20]
#
#   D. [5, 16, 20, 3, 8, 12, 9, 17, 20, 7]

# %% [markdown]
# ## **Métodos de Dividir pra Conquistar**

# %% [markdown]
# Agora voltamos a atenção para a estratégia de “dividir para conquistar” como forma de melhorar o desempenho dos algoritmos de ordenação.

# %% [markdown]
# ### **Merge Sort (Ordenação por Junção)**

# %% [markdown]
# Algoritmo recursivo que divide uma lista continuamente pela metade. Se ela estiver vazia ou possuir um único item, está ordenada por definição (caso base). Se possuir mais de um item, divide-se a lista e invoca-se recursivamente um *Merge Sort* em ambas metades. Assim que as metades estiverem ordenadas, a operação fundamental, chamada de intercalação, é realizada. Intercalar é o processo de pegar duas listas menores ordenadas e combiná-las de modo a formar uma lista nova, única e ordenada. A figura abaixo mostra uma lista sendo dividida pelo *Merge Sort*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A figura abaixo mostra como as listas mais simples, agora ordenadas, são intercaladas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Implementação**

# %%
def merge(alist, lefthalf, righthalf):

    i_left, i_right, i_list = 0, 0, 0

    while i_left < len(lefthalf) and i_right < len(righthalf):

      if lefthalf[i_left] < righthalf[i_right]:

        alist[i_list]=lefthalf[i_left]

        i_left+=1

      else:

        alist[i_list]=righthalf[i_right]

        i_right+=1

      i_list+=1

    while i_left < len(lefthalf):

      alist[i_list]=lefthalf[i_left]

      i_left+=1

      i_list+=1

    while i_right < len(righthalf):

      alist[i_list]=righthalf[i_right]

      i_right+=1

      i_list+=1

    print("Merging ",alist)

# %%
def mergeSort(alist):

  print("Splitting ",alist)

  if len(alist) > 1:

    mid = len(alist) // 2

    lefthalf = alist[:mid]

    righthalf = alist[mid:]

    mergeSort(lefthalf)

    mergeSort(righthalf)

    merge(alist, lefthalf, righthalf)

# %% [markdown]
# ####**Execução**

# %%
alist = [54,26,93,17,77,31,44,55,20]
mergeSort(alist)
print(alist)
# Out:
# Splitting  [54, 26, 93, 17, 77, 31, 44, 55, 20]
# Splitting  [54, 26, 93, 17]
# Splitting  [54, 26]
# Splitting  [54]
# Splitting  [26]
# Merging  [26, 54]
# Splitting  [93, 17]
# Splitting  [93]
# Splitting  [17]
# Merging  [17, 93]
# Merging  [17, 26, 54, 93]
# Splitting  [77, 31, 44, 55, 20]
# Splitting  [77, 31]
# Splitting  [77]
# Splitting  [31]
# Merging  [31, 77]
# Splitting  [44, 55, 20]
# Splitting  [44]
# Splitting  [55, 20]
# Splitting  [55]
# Splitting  [20]
# Merging  [20, 55]
# Merging  [20, 44, 55]
# Merging  [20, 31, 44, 55, 77]
# Merging  [17, 20, 26, 31, 44, 54, 55, 77, 93]
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ####**Análise**

# %% [markdown]
# **Precisamos** considerar os dois processos distintos que compõem sua implementação:

# %% [markdown]
# - Primeiro, a lista é dividida em metades:
#
#  Se começarmos com $n$ itens, em torno de $n/2$ itens sobrarão após a primeira divisão. Depois da segunda divisão, haverá $n/4$, depois $n/8$, $n/16$ e assim por diante. A tabela abaixo mostra quantas vezes é possível dividir a lista.
#
#  ![image.png](data:image/png;base64,...)
#
#  Quando divide-se a lista um número suficiente de vezes, acaba-se ficando com uma lista composta por um único item. O número necessário de divisões para chegar a este ponto é $i$, onde $n/2^{i} = 1$. Isolando $i$, fica-se com $i=log n$. Assim o número máximo de divisões é o logaritmo do número de itens na lista. Portanto, $O(logn)$.

# %% [markdown]
# - Segundo, a intercalação:
#
#   Cada item na lista será processado em algum momento e colocado na lista ordenada. Então a operação de intercalação, que resulta em uma lista de tamanho $n$, requer $n$ operações. O resultado desta análise é: $logn$ divisões, cada qual custando $n$, totalizando $nlogn$ operações. Logo, o merge sort é um algoritmo $O(nlogn)$.

# %% [markdown]
# ####**Exercício**

# %% [markdown]
# 1. Dada a seguinte lista de números: <br> [21, 1, 26, 45, 29, 28, 2, 9, 16, 49, 39, 27, 43, 34, 46, 40] <br> qual resposta mostra a lista que deveria ser ordenada depois de 3 chamadas recursivas do merge sort?
#
#   A. [16, 49, 39, 27, 43, 34, 46, 40]
#
#   B. [21,1]
#
#   C. [21, 1, 26, 45]
#
#   D. [21]

# %% [markdown]
# 2. Dada a seguinte lista de números: <br> [21, 1, 26, 45, 29, 28, 2, 9, 16, 49, 39, 27, 43, 34, 46, 40] <br> qual resposta exibe as duas primeiras listas a serem intercaladas.
#
#   A. [21, 1] e [26, 45]
#
#   B. [1, 2, 9, 21, 26, 28, 29, 45] e [16, 27, 34, 39, 40, 43, 46, 49]
#
#   C. [21] e [1]
#
#   D. [9] e [16]

# %% [markdown]
# ### **Quick Sort**

# %% [markdown]
# Primeiro seleciona um valor, chamado de **pivô**. O papel do **pivô** é ajudar na divisão da lista. A posição à qual o **pivô** pertence de fato na lista ordenada, conhecida como ponto de divisão, será usada para quebrar a lista em chamadas subsequentes do *quick sort*. A figura abaixo mostra que o primeiro elemento funcionará como o primeiro **pivô**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O processo de partição ocorrerá em seguida. Ele irá encontrar o ponto de divisão e, ao mesmo tempo, moverá os itens para o lado apropriado da lista, isto é, maior ou menor que o valor do **pivô**. O particionamento começa localizando dois marcadores de posição: *leftmark* e *rightmark* — no começo e no fim dos demais itens da lista. O objetivo do processo de particionamento é mover os itens que estão do lado errado do **pivô** para o lado certo, convergindo para o ponto de divisão, conforme mostra a figura abaixo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# O algoritmo começa incrementando o *leftmark* até encontrar um valor que seja maior que o valor do **pivô**. Então, decrementa-se o *rightmark* até que se encontre um valor que seja menor que o valor do **pivô**. Nesse instante, descobre-se dois itens que estão fora de ordem em relação ao eventual ponto de divisão. Para o exemplo, isso ocorre com o $93$ e o $20$. Agora é possível trocar esses itens e repetir o processo.
#
# No instante em que *rightmark* se tornar menor que o *leftmark* significa que foi encontrado o ponto de divisão. O valor do **pivô** pode ser trocado com o que estiver no ponto de divisão e o valor do **pivô** estará agora em seu devido lugar. A lista pode agora ser dividida no ponto de divisão e o *quicksort* pode ser chamado recursivamente sobre as duas metades, conforme figura abaixo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Implementação**

# %%
def partition(alist,first,last):

  pivotvalue = alist[first]

  leftmark = first+1

  rightmark = last

  while True:

    while leftmark <= rightmark and alist[leftmark] <= pivotvalue:

      leftmark = leftmark + 1

    while alist[rightmark] >= pivotvalue and rightmark >= leftmark:

      rightmark = rightmark - 1

    if rightmark < leftmark:

      break

    else:

      alist[leftmark], alist[rightmark] = alist[rightmark], alist[leftmark]

  alist[first], alist[rightmark] = alist[rightmark], alist[first]

  return rightmark

# %%
def quickSort(alist,first=0,last=None):

  if last == None:

    last = len(alist)-1

  if first<last:

    splitpoint = partition(alist,first,last)

    quickSort(alist,first,splitpoint-1) # left

    quickSort(alist,splitpoint+1,last) # right

# %% [markdown]
# ####**Execução**

# %%
alist = [54,26,93,17,77,31,44,55,20]
quickSort(alist)
print(alist)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# ####**Análise**

# %% [markdown]
# Para uma lista de tamanho $n$, se a partição sempre ocorre no meio da lista, haverá de novo $logn$ divisões. Contudo, não há necessidade de memória adicional como no caso do *merge sort*. Para encontrar o ponto de divisão, cada um dos $n$ itens precisa ser comparado com o valor do **pivô**. O resultado é $nlogn$. No pior caso, os pontos de divisão podem não estar no meio. Na verdade, eles podem tender muito à esquerda ou à direita, criando uma separação desigual. Nesse caso, ordenar uma lista de $n$ itens poderia dividir a lista em $0$ itens de um lado $n−1$ do outro. Ordenar uma lista de $n-1$, por sua vez, resultaria na divisão de uma lista de tamanho $0$ de um lado e $n−2$ do outro, e assim por diante. O resultado disso é uma ordenação da ordem $O(n²)$ com o custo tipicamente requerido por chamadas recursivas.

# %% [markdown]
# ####**Exercício**

# %% [markdown]
# 1. Dada a seguinte lista de números [14, 17, 13, 15, 19, 10, 3, 16, 9, 12], qual resposta mostra a lista correta após o segundo particionamento, de acordo com o algoritmo do quicksort?
#
#  A. [9, 3, 10, 13, 12]
#
#  B. [9, 3, 10, 13, 12, 14]
#
#  C. [9, 3, 10, 13, 15, 14, 17, 16, 12, 19]
#
#  D. [9, 3, 10, 13, 12, 14, 19, 16, 15, 17]
